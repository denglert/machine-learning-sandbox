# %% [markdown]
# # Cross entropy

# %% [markdown]
# For continuous case:
#
# \begin{equation}
#     H
#     =
#     - \int p(x) \log q(x) dx
# \end{equation}
#
# For discrete case:
#
# \begin{equation}
#     H
#     =
#     - \sum_{i}
#     p(x_{i}) \log q(x_{i})
# \end{equation}

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from information_theory.measures import *

# %%
def normalize(w):
    return w/sum(w)

# %%
def plot_distributions(pdf1, pdf2):
    fig, ax = plt.subplots()
    x = np.arange(len(pdf1))
    ax.bar(x-0.15, pdf1, color='firebrick', width=0.3, edgecolor='k', label='1', alpha=0.5)
    ax.bar(x+0.15, pdf2, color='navy', width=0.3, edgecolor='k', label='2', alpha=0.5)
    ax.legend()
    h = cross_entropy(pdf1, pdf2)
    ax.set_title("Cross entropy: {:.3f}".format(h))
    return fig, ax

# %%
def create_dashboard(w1, w2):
    w1 = np.array(w1)
    w2 = np.array(w2)
    pdf1 = normalize(w1)
    pdf2 = normalize(w2)
    fig, ax = plot_distributions(pdf1, pdf2)

# %% [markdown]
# ## Binary case

# %% [markdown]
# \begin{equation}
#      H
#     =
#     - \sum_{i}
#     p(x_{i}) \log q(x_{i})
# \end{equation}

# %%
create_dashboard([1.0, 0.0], [1.0, 0.0])
# Out:
# /home/edy/lib/build/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
create_dashboard([0.9, 0.1], [0.9, 0.1])

# %%
create_dashboard([0.5, 0.5], [0.5, 0.5])

# %%
create_dashboard([1.0, 0.0], [0.9, 0.1])

# %%
create_dashboard([1.0, 0.0], [0.99, 0.01])

# %%
q1 = np.linspace(0.0, 1.0, 1000)

# %%
h = [cross_entropy(np.array([1.0, 0]), np.array([x, 1.0-x])) for x in q1]
fig, ax = plt.subplots()
ax.scatter(q1, h)
# Out:
# /home/edy/lib/build/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
h = [cross_entropy(np.array([0.0, 1.0]), np.array([x, 1.0-x])) for x in q1]
fig, ax = plt.subplots()
ax.scatter(q1, h)
# Out:
# /home/edy/lib/build/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
h = [cross_entropy(np.array([x, 1.0-x]), np.array([x, 1.0-x])) for x in q1]
fig, ax = plt.subplots()
ax.scatter(q1, h)
# Out:
# /home/edy/lib/build/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
w1 = np.array([1.4, 5.4, 7.8, 1.2, 5.5])
w2 = np.array([0.1, 9.0, 1.1, 1.1, 3.3])
p = normalize(w1)
q = normalize(w2)
